# %%
import pandas as pd
import numpy as np
from numpy.random import randn
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# # Line Chart

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]

plt.plot(x,y)

# %%
df = DataFrame(data={'column 1': [1,2,3,6,7,3,9,2], 
              'column 2': [16,19,12,13,11,11,14,15]})
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bar Chart

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
df.plot(kind='bar') #vertical
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='barh') #horizontal
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pie Chart

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# # Saving a Plot

# %%
plt.pie(x)
plt.savefig('pie_chart.png')

# %%
# %pwd #showing the path to current directory
# Out:
# '/Users/user/Desktop/Python Tricks for Data Science'

# %% [markdown]
# # Histogram

# %%
import seaborn as sb

sb.set_style('whitegrid')

# %%
cars = pd.read_csv('mtcars.csv')
cars.columns = ['car_names','mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
cars.index = cars.car_names

mpg = cars['mpg']
mpg.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(mpg)
plt.plot()
# Out:
# []

# %%
sb.distplot(mpg)
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %% [markdown]
# # Scatter Plot

# %%
cars.plot(kind='scatter', x = 'hp', y='mpg', c=['darkgray'], s=150)
# Out:
# <AxesSubplot:xlabel='hp', ylabel='mpg'>

# %%
sb.regplot(data=cars, x='hp', y='mpg')
# Out:
# <AxesSubplot:xlabel='hp', ylabel='mpg'>

# %%
cars_subset = cars[['mpg', 'disp', 'hp', 'wt']]
cars_subset
# Out:
#                       mpg   disp   hp     wt
# car_names
# Mazda RX4            21.0  160.0  110  2.620
# Mazda RX4 Wag        21.0  160.0  110  2.875
# Datsun 710           22.8  108.0   93  2.320
# Hornet 4 Drive       21.4  258.0  110  3.215
# Hornet Sportabout    18.7  360.0  175  3.440
# Valiant              18.1  225.0  105  3.460
# Duster 360           14.3  360.0  245  3.570
# Merc 240D            24.4  146.7   62  3.190
# Merc 230             22.8  140.8   95  3.150
# Merc 280             19.2  167.6  123  3.440
# Merc 280C            17.8  167.6  123  3.440
# Merc 450SE           16.4  275.8  180  4.070
# Merc 450SL           17.3  275.8  180  3.730
# Merc 450SLC          15.2  275.8  180  3.780
# Cadillac Fleetwood   10.4  472.0  205  5.250
# Lincoln Continental  10.4  460.0  215  5.424
# Chrysler Imperial    14.7  440.0  230  5.345
# Fiat 128             32.4   78.7   66  2.200
# Honda Civic          30.4   75.7   52  1.615
# Toyota Corolla       33.9   71.1   65  1.835
# ...

# %%
sb.pairplot(cars_subset)

# %% [markdown]
# # Boxplot

# %%
cars.boxplot(column = 'mpg', by='am')
cars.boxplot(column = 'wt', by='am')
# Out:
# <AxesSubplot:title={'center':'wt'}, xlabel='am'>

# %%
sb.boxplot(data = cars, x = 'am', y = 'mpg', palette='hls')
# Out:
# <AxesSubplot:xlabel='am', ylabel='mpg'>
